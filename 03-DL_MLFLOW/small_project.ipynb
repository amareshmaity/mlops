# %% [markdown]
# ## Small project with hyperopt for DL

# %%
import pandas as pd
import numpy as np

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Normalization

from hyperopt import STATUS_OK, Trials, fmin, hp, tpe

import mlflow
from mlflow.models import infer_signature
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       3
#       4 from tensorflow.keras.models import Sequential
#       5 from tensorflow.keras.layers import Dense, Normalization
#       6
# ----> 7 from hyperopt import STATUS_OK, Trials, fmin, hp, tpe
#       8
#       9 import mlflow
#      10 from mlflow.models import infer_signature
#
# File e:\AI\mlops\venv\Lib\site-packages\hyperopt\__init__.py:34
#      32 from . import rand
#      33 from . import tpe
# ---> 34 from . import atpe
#      35 from . import mix
#      36 from . import anneal
#
# File e:\AI\mlops\venv\Lib\site-packages\hyperopt\atpe.py:19
#      17 import numpy
#      18 import numpy.random
# ---> 19 import pkg_resources
#      20 import tempfile
#      21 import scipy.stats
#
# ModuleNotFoundError: No module named 'pkg_resources'

# %%
import keras
import numpy as np
import pandas as pd
from hyperopt import STATUS_OK,Trials,fmin,hp,tpe
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

import mlflow
from mlflow.models import infer_signature
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       1 import keras
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 from hyperopt import STATUS_OK,Trials,fmin,hp,tpe
#       5 from sklearn.metrics import mean_squared_error
#       6 from sklearn.model_selection import train_test_split
#       7
#
# File e:\AI\mlops\venv\Lib\site-packages\hyperopt\__init__.py:34
#      32 from . import rand
#      33 from . import tpe
# ---> 34 from . import atpe
#      35 from . import mix
#      36 from . import anneal
#
# File e:\AI\mlops\venv\Lib\site-packages\hyperopt\atpe.py:19
#      17 import numpy
#      18 import numpy.random
# ---> 19 import pkg_resources
#      20 import tempfile
#      21 import scipy.stats
#
# ModuleNotFoundError: No module named 'pkg_resources'
